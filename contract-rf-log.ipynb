# %%
import pandas as pd
import tensorflow as tf
from pathlib import Path
from defi_lend_eval.modelling import contract
from defi_lend_eval.preprocess.contract import pre_process_data

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# p = Path('/mnt/d/projects/Defi-Lending-Evaluation/data/')
p = Path('/run/media/da/Data/Projects/DeFi-Lending-Evaluation/data/')
fnames = contract.find_data_file(p, '_matrix.csv')
df = contract.read_data(fnames)
df = df.dropna()
display(df.shape)
df.head()
# Out:
# (19392, 17)
#      commit     la   ld  ns  nd  nf       ent  nuc  ndev       inter  exp  \
# 0  ca96d695    966   37   3   7  14  1.332095   62     1   64.008765  210
# 1  1d02a6bb      7    7   3   4   5  1.220036   29     1  294.411611  117
# 2  33639778  24751  115   2   3  44  1.089848   39     2  569.835787   91
# 3  2383726a      3    1   1   1   1  0.026486   59     1  118.513333  152
# 4  d01b89b9     31   19   3   3  11  3.046779   10     1   16.237778   77
#
#        rexp  sexp       pod    fix  buggy          plat
# 0  0.029312   188  1.000000  False  False  88mph_matrix
# 1  0.004706    44  1.000000  False  False  88mph_matrix
# 2  0.020129    26  0.487179  False   True  88mph_matrix
# 3  0.402389   104  1.000000   True  False  88mph_matrix
# 4  0.006936    26  1.000000   True  False  88mph_matrix

# %%
fnames = contract.find_data_file(p, 'commits.json')
used_df = contract.read_data(fnames, 'json')
used_df = used_df.dropna()
used_df.head()
# Out:
#      commit                                                msg  \
# 0  f57cf8a6      Add storage gaps to Rescuable and Sponsorable
# 1  0a0c5a83                            Fixed best practices 10
# 2  b5b618bc  Update deploy scripts for money markets & Dump...
# 3  005cb00a                         Refactor test dependencies
# 4  2fdfecf9                      Fix ERC20Wrapper::_transfer()
#
#                                              changes  buggy  \
# 0  diff --git a/contracts/libs/Rescuable.sol b/co...  False
# 1  diff --git a/contracts/DInterest.sol b/contrac...   True
# 2  diff --git a/contracts/mocks/VaultMock.sol b/c...  False
# 3  diff --git a/test/DInterest.test.js b/test/DIn...  False
# 4  diff --git a/contracts/libs/ERC20Wrapper.sol b...  False
#
#                   plat
# 0  88mph_buggy_commits
# 1  88mph_buggy_commits
# 2  88mph_buggy_commits
# 3  88mph_buggy_commits
# 4  88mph_buggy_commits

# %%
used_df = used_df.drop(['plat'], axis=1)
used_df.head()
# Out:
#      commit                                                msg  \
# 0  f57cf8a6      Add storage gaps to Rescuable and Sponsorable
# 1  0a0c5a83                            Fixed best practices 10
# 2  b5b618bc  Update deploy scripts for money markets & Dump...
# 3  005cb00a                         Refactor test dependencies
# 4  2fdfecf9                      Fix ERC20Wrapper::_transfer()
#
#                                              changes  buggy
# 0  diff --git a/contracts/libs/Rescuable.sol b/co...  False
# 1  diff --git a/contracts/DInterest.sol b/contrac...   True
# 2  diff --git a/contracts/mocks/VaultMock.sol b/c...  False
# 3  diff --git a/test/DInterest.test.js b/test/DIn...  False
# 4  diff --git a/contracts/libs/ERC20Wrapper.sol b...  False

# %%
used_df = used_df[['commit', 'changes', 'buggy']]
used_df['changes'] = used_df['changes'].apply(lambda x:pre_process_data(x))
used_df.dropna(inplace=True)
display(used_df.shape)
used_df.head()
# Out:
# (19392, 3)
#      commit                                            changes  buggy
# 0  f57cf8a6  +\n+    uint256[50] private __gap;\n+\n+    ui...  False
# 1  0a0c5a83  +        uint256 _UIRMultiplier, // Upfront in...   True
# 2  b5b618bc  +\n+    function pricePerShare() external view...  False
# 3  005cb00a  +const Base = require('./base')\n+  const INIT...  False
# 4  2fdfecf9  +        parentMultitoken.wrapperTransfer(send...  False

# %%
import re
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer

def lower_case(txt):
    """ turn all letters into lower case """
    return str(txt).lower()

def rm_special_words(txt):
    """ remove all sepcial words """
    # remove special charaecters
    txt = re.sub(r'[\!\#\$\%\&\(\)\*+\,\-\.\/\;\:\<\=\>\?\@\[\]\\\^\_\`\{\}\|\~\n]', ' ', txt)
    # replace number and string literals with sepcial tokens
    txt = re.sub(r"([\d ]+)", " <NUM> ", txt)
    txt = re.sub(r"(\".*?\")", " <STR> ", txt)
    txt = re.sub(r"(\'.*?\')", " <STR> ", txt)
    return txt
    
def filter_words(words):
    """ remove punctuations and stopwords """
    stops = stopwords.words("english")
    words = [w for w in words if (w.isalpha() and w not in stops)]
    return words
    
def stem_words(words):
    """ perform words stemming """
    snowball = SnowballStemmer("english")
    words = [snowball.stem(w) for w in words]
    return words
    
def preprocess(txt):
    """ required preprocessing """
    # txt = lower_case(txt)
    txt = rm_special_words(txt)
    return txt

# %%
used_df['words'] = used_df['changes'].apply(lambda x : preprocess(x))
used_df.head()
# Out:
#      commit                                            changes  buggy  \
# 0  f57cf8a6  +\n+    uint256[50] private __gap;\n+\n+    ui...  False
# 1  0a0c5a83  +        uint256 _UIRMultiplier, // Upfront in...   True
# 2  b5b618bc  +\n+    function pricePerShare() external view...  False
# 3  005cb00a  +const Base = require('./base')\n+  const INIT...  False
# 4  2fdfecf9  +        parentMultitoken.wrapperTransfer(send...  False
#
#                                                words
# 0   <NUM> uint <NUM> private <NUM> gap <NUM> uint...
# 1   <NUM> uint <NUM> UIRMultiplier <NUM> Upfront ...
# 2   <NUM> function <NUM> pricePerShare <NUM> exte...
# 3   <NUM> const <NUM> Base <NUM> require <NUM>  <...
# 4   <NUM> parentMultitoken <NUM> wrapperTransfer ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer()
cv_fit = cv.fit_transform(used_df['words'].tolist())

# %%
display(len(cv.get_feature_names()))
used_df['nw'] = cv_fit.toarray().sum(axis=1)
used_df.head()
# Out:
# 118263
#      commit                                            changes  buggy  \
# 0  f57cf8a6  +\n+    uint256[50] private __gap;\n+\n+    ui...  False
# 1  0a0c5a83  +        uint256 _UIRMultiplier, // Upfront in...   True
# 2  b5b618bc  +\n+    function pricePerShare() external view...  False
# 3  005cb00a  +const Base = require('./base')\n+  const INIT...  False
# 4  2fdfecf9  +        parentMultitoken.wrapperTransfer(send...  False
#
#                                                words    nw
# 0   <NUM> uint <NUM> private <NUM> gap <NUM> uint...    13
# 1   <NUM> uint <NUM> UIRMultiplier <NUM> Upfront ...   205
# 2   <NUM> function <NUM> pricePerShare <NUM> exte...   839
# 3   <NUM> const <NUM> Base <NUM> require <NUM>  <...  5087
# 4   <NUM> parentMultitoken <NUM> wrapperTransfer ...    13

# %%
idx = cv.get_feature_names().index('function')
used_df['nfunc'] = cv_fit.toarray()[:,idx]
used_df.head()
# Out:
#      commit                                            changes  buggy  \
# 0  f57cf8a6  +\n+    uint256[50] private __gap;\n+\n+    ui...  False
# 1  0a0c5a83  +        uint256 _UIRMultiplier, // Upfront in...   True
# 2  b5b618bc  +\n+    function pricePerShare() external view...  False
# 3  005cb00a  +const Base = require('./base')\n+  const INIT...  False
# 4  2fdfecf9  +        parentMultitoken.wrapperTransfer(send...  False
#
#                                                words    nw  nfunc
# 0   <NUM> uint <NUM> private <NUM> gap <NUM> uint...    13      0
# 1   <NUM> uint <NUM> UIRMultiplier <NUM> Upfront ...   205      0
# 2   <NUM> function <NUM> pricePerShare <NUM> exte...   839      5
# 3   <NUM> const <NUM> Base <NUM> require <NUM>  <...  5087      0
# 4   <NUM> parentMultitoken <NUM> wrapperTransfer ...    13      0

# %%
df = pd.merge(df, used_df, on=['commit','buggy'])
df.drop(['changes', 'plat', 'words'], axis=1, inplace=True)
df.head()
# Out:
#      commit     la   ld  ns  nd  nf       ent  nuc  ndev       inter  exp  \
# 0  ca96d695    966   37   3   7  14  1.332095   62     1   64.008765  210
# 1  1d02a6bb      7    7   3   4   5  1.220036   29     1  294.411611  117
# 2  33639778  24751  115   2   3  44  1.089848   39     2  569.835787   91
# 3  2383726a      3    1   1   1   1  0.026486   59     1  118.513333  152
# 4  d01b89b9     31   19   3   3  11  3.046779   10     1   16.237778   77
#
#        rexp  sexp       pod    fix  buggy    nw  nfunc
# 0  0.029312   188  1.000000  False  False  3612     29
# 1  0.004706    44  1.000000  False  False    25      0
# 2  0.020129    26  0.487179  False   True    95      0
# 3  0.402389   104  1.000000   True  False    15      0
# 4  0.006936    26  1.000000   True  False   271      0

# %%
# remove commit with too many added lines, since those changes may mainly due to
# the modification of configurations files (like json, yaml, and so on.)
# q99 = df['la'].quantile(0.995)
# display(q99)
# df = df[df['la'] < q99]
# display(df.shape)

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.3, random_state=28)
display(test['buggy'].value_counts())
display(train['buggy'].value_counts())
# Out:
# False    5463
# True      382
# Name: buggy, dtype: int64
# False    12766
# True       871
# Name: buggy, dtype: int64

# %%
train_x = train.drop(['commit', 'buggy'], axis=1)
train_y = train['buggy']
display(train_x)
train_y
# Out:
#          la  ld  ns  nd  nf       ent  nuc  ndev       inter  exp      rexp  \
# 1235      7   0   1   1   1  0.464386    9     3    5.821667   22  0.048633
# 11044    63   4   1   1   2  0.478223   38     6    1.226667   32  0.019554
# 14910    17   9   8   8   8  1.851868   26     4    0.042222  451  1.067220
# 15300     1   1   1   1   1  0.013453    3     3  522.352500    0  0.000000
# 8367    158  10   2   2   2  0.258672  104     5  141.811944  869  0.003806
# ...     ...  ..  ..  ..  ..       ...  ...   ...         ...  ...       ...
# 16471     6   3   1   1   1  0.370989    1     2   26.853056  422  0.008943
# 7427     39   4   1   2   2  0.744302   23     2   17.378333   45  0.199736
# 7200   3897   2   1   1   1  0.437606  340    14  172.863056   11  0.446245
# 4089     64   8   1   1   2  0.134793  142     4    0.300833  173  0.003357
# 9473      3   0   1   1   1  0.126915   74     8  241.635833  242  0.082168
#
#        sexp       pod    fix   nw  nfunc
# 1235     16  0.000000  False   45      0
# 11044    22  0.184211  False  371      0
# 14910   191  0.576923  False    0      0
# 15300     0  0.000000   True   13      0
# 8367    535  0.942308   True  199      0
# ...     ...       ...    ...  ...    ...
# 16471   126  0.000000   True   48      0
# 7427     26  0.391304  False  456      0
# 7200      4  0.002941  False    0      0
# 4089     84  0.521127  False    0      0
# 9473     59  0.067568  False    0      0
#
# [13637 rows x 16 columns]
# 1235     False
# 11044    False
# 14910    False
# 15300    False
# 8367     False
#          ...
# 16471    False
# 7427     False
# 7200     False
# 4089     False
# 9473     False
# Name: buggy, Length: 13637, dtype: bool

# %%
from imblearn.over_sampling import SMOTE

x_resampled, y_resampled = SMOTE(random_state=131).fit_resample(train_x, train_y)
display(x_resampled.shape)
display(x_resampled)
display(y_resampled.shape)
display(y_resampled)
display(y_resampled.value_counts())
# Out:
# (25532, 16)
#         la  ld  ns  nd  nf       ent  nuc  ndev       inter  exp      rexp  \
# 0        7   0   1   1   1  0.464386    9     3    5.821667   22  0.048633
# 1       63   4   1   1   2  0.478223   38     6    1.226667   32  0.019554
# 2       17   9   8   8   8  1.851868   26     4    0.042222  451  1.067220
# 3        1   1   1   1   1  0.013453    3     3  522.352500    0  0.000000
# 4      158  10   2   2   2  0.258672  104     5  141.811944  869  0.003806
# ...    ...  ..  ..  ..  ..       ...  ...   ...         ...  ...       ...
# 25527   70  43   3   5  10  1.270712  175     6  550.285282   94  0.010118
# 25528   13   1   1   1   1  0.344159    1     1    0.251463   54  0.354263
# 25529    3   4   2   2   2  0.463835   10     1   11.164827   11  0.129603
# 25530  169  18   1   2   4  0.454045  320     8  439.088240  372  0.063925
# 25531   16   3   2   2   3  0.361441   55     3   50.907222   74  0.084851
#
#        sexp       pod    fix   nw  nfunc
# 0        16  0.000000  False   45      0
# 1        22  0.184211  False  371      0
# 2       191  0.576923  False    0      0
# 3         0  0.000000   True   13      0
# 4       535  0.942308   True  199      0
# ...     ...       ...    ...  ...    ...
# 25527    79  0.234106   True  452      0
# 25528    17  0.956430  False  110      0
# 25529     8  1.000000  False    6      0
# 25530   216  0.322211  False  181      0
# 25531    47  0.356120   True   65      0
#
# [25532 rows x 16 columns]
# (25532,)
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25527     True
# 25528     True
# 25529     True
# 25530     True
# 25531     True
# Name: buggy, Length: 25532, dtype: bool
# True     12766
# False    12766
# Name: buggy, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

rf = RandomForestClassifier(n_estimators=300, random_state=28, criterion='entropy', max_features=5)
rf.fit(x_resampled, y_resampled)
# rf.fit(StandardScaler().fit_transform(x_resampled), y_resampled
# Out:
# RandomForestClassifier(criterion='entropy', max_features=5, n_estimators=300,
#                        random_state=28)

# %%
test_x = test.drop(['commit', 'buggy'], axis=1)
test_y = test['buggy']

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, f1_score

predictions = rf.predict(test_x)
report = classification_report(test_y, predictions)
unique_label = np.unique([test_y, predictions])
cmtx = pd.DataFrame(
    confusion_matrix(test_y, predictions, labels=unique_label), 
    index=['true:{:}'.format(x) for x in unique_label], 
    columns=['pred:{:}'.format(x) for x in unique_label]
)
print(report)
print(cmtx)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.96      0.93      0.94      5463
#         True       0.30      0.43      0.35       382
#
#     accuracy                           0.90      5845
#    macro avg       0.63      0.68      0.65      5845
# weighted avg       0.92      0.90      0.90      5845
#
#             pred:False  pred:True
# true:False        5070        393
# true:True          216        166

# %%
pred_prob = rf.predict_proba(test_x)

max_score = 0
th = 0

for i in range(1, 100):
    pred2 = (pred_prob[:,1] >= i/100)
    score = f1_score(test_y, pred2)
    if score > max_score:
        max_score = score
        th = i/100

print(f'Threshhold: {th}; Max-Score: {max_score}')
pred2 = (pred_prob[:,1] >= 0.43)
rep2 = classification_report(test_y, pred2)
print(rep2)
print(confusion_matrix(test_y, pred2))
# Out:
# Threshhold: 0.55; Max-Score: 0.3730061349693252
#               precision    recall  f1-score   support
#
#        False       0.96      0.90      0.93      5463
#         True       0.25      0.51      0.34       382
#
#     accuracy                           0.87      5845
#    macro avg       0.61      0.70      0.63      5845
# weighted avg       0.92      0.87      0.89      5845
#
# [[4890  573]
#  [ 186  196]]

# %%
import joblib

joblib.dump(rf, "models/random_forest.joblib")
# Out:
# ['models/random_forest.joblib']
